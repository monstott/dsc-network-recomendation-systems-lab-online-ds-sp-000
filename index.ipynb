# %% [markdown]
# # Recommendation Systems - Lab
#
# ## Introduction
#
# Now that you've gotten an introduction to collaborative filtering and recommendation systems, it's time to put your skills to test and attempt to build a recommendation system for a real world dataset! For this exercise, you'll be using a dataset regarding the book reviews on the Amazon marketplace. While the previous lesson focused on user-based recommendation systems, you'll apply a parallel process for an item-based recommendation system to recommend similar books at the bottom of the product page.
#
# ## Objectives
#
# You will be able to:
# * Implement a recommendation system on a real world dataset

# %% [markdown]
# ## Load the Dataset

# %%
#Your code here
import pandas as pd

df = pd.read_csv('books_data.edgelist', names=['source', 'target', 'weight'], delimiter=' ')
df.head()
# Out:
#        source      target  weight
# 0  0827229534  0804215715     0.7
# 1  0827229534  156101074X     0.5
# 2  0827229534  0687023955     0.8
# 3  0827229534  0687074231     0.8
# 4  0827229534  082721619X     0.7

# %% [markdown]
# ## Load the MetaData

# %%
#Your code here
meta = pd.read_csv('books_meta.txt', sep='\t')
print(meta.shape)
meta.head()
# Out:
# (393561, 10)
#    Id        ASIN                                              Title  \
# 0   1  0827229534            Patterns of Preaching: A Sermon Sampler
# 1   2  0738700797                         Candlemas: Feast of Flames
# 2   3  0486287785   World War II Allied Fighter Planes Trading Cards
# 3   4  0842328327  Life Application Bible Commentary: 1 and 2 Tim...
# 4   5  1577943082    Prayers That Avail Much for Business: Executive
#
#                                           Categories Group  SalesRank  \
# 0  clergi sermon subject religion preach spiritu ...  Book     396585
# 1  subject witchcraft earth religion spiritu base...  Book     168596
# 2       general hobbi subject craft home garden book  Book    1270652
# 3  spiritu translat commentari christian book gui...  Book     631289
# 4  subject religion spiritu busi christian live w...  Book     455160
#
#    TotalReviews  AvgRating  DegreeCentrality  ClusteringCoeff
# 0             2        5.0                 8             0.80
# 1            12        4.5                 9             0.85
# 2             1        5.0                 0             0.00
# 3             1        4.0                 6             0.79
# 4             0        0.0                 4             1.00

# %% [markdown]
# ## Select Books to Test Your Recommender On
#
# Select a small subset of books that you are interested in generating recommendations for.

# %%
#Your code here
Data = meta[meta.Title.str.contains('Data Analysis for')]
Data
# Out:
#             Id        ASIN                                              Title  \
# 42708    59816  0205289037                   Data Analysis for Social Workers
# 101211  141127  0761987363  Theory Based Data Analysis for the Social Scie...
# 162675  226907  0333763068  Data Construction and Data Analysis for Survey...
# 171894  239492  0471489786  Chemometrics : Data Analysis for the Laborator...
# 182498  254370  0963502700         Data Analysis for Scientists and Engineers
# 208649  290685  0761901078  Methods and Data Analysis for Cross-Cultural R...
# 232943  323459  0412063417   Practical Data Analysis for Designed Experiments
# 301564  416769  0521009766  Experimental Design and Data Analysis for Biol...
# 358834  494701  0764516612                    Excel Data Analysis for Dummies
# 381258  525611  0750650869                  Data Analysis for Database Design
#
#                                                Categories Group  SalesRank  \
# 42708   nonfict appli mathemat subject statist technic...  Book     582429
# 101211  general nonfict subject statist sociolog socia...  Book     718337
# 162675  general nonfict subject home invest statist bu...  Book     723293
# 171894  general subject chemic analyt chemistri techni...  Book     298288
# 182498  general appli mathemat subject statist technic...  Book     506891
# 208649  mind general counsel nonfict subject health bo...  Book     737355
# 232943  busi technic book com probabl offic general su...  Book     743779
# 301564  biolog general subject methodolog educ experi ...  Book      90629
# 358834  introductori book spreadsheet com guid offic d...  Book      27397
# 381258  analysi system busi book com offic databas gen...  Book    1203883
#
#         TotalReviews  AvgRating  DegreeCentrality  ClusteringCoeff
# 42708              0        0.0                 2             0.00
# 101211             0        0.0                 0             0.00
# 162675             0        0.0                 0             0.00
# 171894             0        0.0                 3             0.00
# 182498             2        4.5                 5             0.90
# 208649             0        0.0                 2             0.00
# 232943             0        0.0                 0             0.00
# 301564             0        0.0                19             0.48
# 358834             1        5.0                 4             0.70
# 381258             1        4.0                 0             0.00

# %% [markdown]
# ## Generate Recommendations for a Few Books of Choice
#
# The 'books_data.edgelist' has conveniently already calculated the distance between items for you. Given this preprocessed and data, it's time to employ collaborative filtering to generate recommendations! Generate the top 10 recommendations for each book in the subset you chose. Be sure to print the book name that you are generating recommendations for as well as the name of the books being recommended.

# %%
#Your code here
rec_dict = {}
id_name_dict = dict(zip(meta.ASIN, meta.Title))
for row in Data.index:
    book_id = Data.ASIN[row]
    book_name = id_name_dict[book_id]
    most_similar = df[(df.source == book_id) | (df.target == book_id)].sort_values(by='weight', ascending=False).head(10)
    most_similar['source_name'] = most_similar['source'].map(id_name_dict)
    most_similar['target_name'] = most_similar['target'].map(id_name_dict)
    
    recommendations = []
    for row in most_similar.index:
        if most_similar.source[row] == book_id:
            recommendations.append((most_similar.target_name[row], most_similar.weight[row]))
        else:
            recommendations.append((most_similar.source_name[row], most_similar.weight[row]))
    rec_dict[book_name] = recommendations
    print("Recommendations for:", book_name)
    for r in recommendations:
        print(r)
    print('\n')
# Out:
# Recommendations for: Data Analysis for Social Workers
# ('Management of Human Service Programs', 0.17)
# ('Becoming an Effective Policy Advocate: From Policy Practice to Social Justice', 0.16)
#
#
# Recommendations for: Theory Based Data Analysis for the Social Sciences (Undergraduate Research Methods & Statistics in the Social Sciences)
#
#
# Recommendations for: Data Construction and Data Analysis for Survey Research
#
#
# Recommendations for: Chemometrics : Data Analysis for the Laboratory and Chemical Plant
# ('Statistics and Chemometrics for Analytical Chemistry (4th Edition)', 0.7)
# ('Statistics for Experimenters: An Introduction to Design, Data Analysis, and Model Building', 0.28)
# ('Multivariate Statistical Analysis: A Conceptual Introduction', 0.0)
#
#
# Recommendations for: Data Analysis for Scientists and Engineers
# ('Data Reduction and Error Analysis for the Physical Sciences', 0.83)
# ('An Introduction to Error Analysis: The Study of Uncertainties in Physical Measurements', 0.54)
# ('The Statistical Analysis of Experimental Data', 0.53)
# ('Measurement Errors and Uncertainties : Theory and Practice', 0.41)
# ('Statistics: A Guide to the Use of Statistical Methods in the Physical Sciences (Manchester Physics Series)', 0.0)
#
#
# Recommendations for: Methods and Data Analysis for Cross-Cultural Research (Cross Cultural Psychology)
# ('The Handbook of Culture & Psychology', 0.63)
# ('Cross-Cultural Survey Methods (Wiley Series in Survey Methodology)', 0.29)
#
#
# Recommendations for: Practical Data Analysis for Designed Experiments
#
#
# Recommendations for: Experimental Design and Data Analysis for Biologists
# ('Design and Analysis of Ecological Experiments', 0.78)
# ('Multivariate Statistics for Wildlife and Ecology Research', 0.74)
# ('Ecological Methodology (2nd Edition)', 0.61)
# ('Multivariate Statistics for Wildlife and Ecology Research', 0.57)
# ('Introductory Biological Statistics', 0.5)
# ('Spreadsheet Exercises in Ecology and Evolution', 0.47)
# ("Choosing and Using Statistics: A Biologist's Guide", 0.47)
# ('Data Analysis in Community and Landscape Ecology', 0.47)
# ('Biometry', 0.47)
# ('Null Models in Ecology', 0.4)
#
#
# Recommendations for: Excel Data Analysis for Dummies
# ('Accessing and Analyzing Data with Microsoft Excel', 0.82)
# ('Guerilla Data Analysis Using Microsoft Excel', 0.82)
# ('Excel Data Analysis: Your Visual Blueprint for Creating and Analyzing Data, Charts and PivotTables', 0.58)
# ('Statistics for Dummies', 0.07)
#
#
# Recommendations for: Data Analysis for Database Design

# %% [markdown]
# ## Summary
#
# Well done! In this lab, you effectively created a recommendation system for a real world dataset!
